# %%
import pandas as pd

filmes = pd.read_csv('ml-latest-small/movies.csv')
filmes.columns = ['filmeId', 'titulo', 'generos']
filmes = filmes.set_index('filmeId')
filmes.head()
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              generos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy

# %%
notas = pd.read_csv('ml-latest-small/ratings.csv')
notas.columns = ['usuarioId', 'filmeId', 'nota', 'momento']
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.describe()
# Out:
#            usuarioId        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %% [markdown]
# # Primeira tentativa de recomendação

# %% [markdown]
# ### Que seria recomendando os mais populares (os mais votados) para qualquer pessoal

# %%
total_de_votos = notas['filmeId'].value_counts()
total_de_votos.head()
# Out:
# 356     329
# 318     317
# 296     307
# 593     279
# 2571    278
# Name: filmeId, dtype: int64

# %%
filmes.loc[356]
# Out:
# titulo          Forrest Gump (1994)
# generos    Comedy|Drama|Romance|War
# Name: 356, dtype: object

# %%
filmes['total_de_votos'] = total_de_votos
filmes
# Out:
#                                             titulo  \
# filmeId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                              generos  total_de_votos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 2                         Adventure|Children|Fantasy           110.0
# 3                                     Comedy|Romance            52.0
# 4                               Comedy|Drama|Romance             7.0
# 5                                             Comedy            49.0
# ...                                              ...             ...
# 193581               Action|Animation|Comedy|Fantasy             1.0
# 193583                      Animation|Comedy|Fantasy             1.0
# 193585                                         Drama             1.0
# 193587                              Action|Animation             1.0
# 193609                                        Comedy             1.0
#
# [9742 rows x 3 columns]

# %%
# false, pois assim ele fica na ordem descendente 
filmes.sort_values('total_de_votos', ascending = False).head(10)
# Out:
#                                             titulo  \
# filmeId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                   generos  total_de_votos
# filmeId
# 356              Comedy|Drama|Romance|War           329.0
# 318                           Crime|Drama           317.0
# 296           Comedy|Crime|Drama|Thriller           307.0
# 593                 Crime|Horror|Thriller           279.0
# 2571               Action|Sci-Fi|Thriller           278.0
# 260               Action|Adventure|Sci-Fi           251.0
# 480      Action|Adventure|Sci-Fi|Thriller           238.0
# 110                      Action|Drama|War           237.0
# 589                         Action|Sci-Fi           224.0
# 527                             Drama|War           220.0

# %%
notas_medias = notas.groupby('filmeId').mean()['nota']
notas_medias.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
filmes['nota_media'] = notas_medias
filmes.sort_values('total_de_votos', ascending = False).head(10)
# Out:
#                                             titulo  \
# filmeId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                   generos  total_de_votos  nota_media
# filmeId
# 356              Comedy|Drama|Romance|War           329.0    4.164134
# 318                           Crime|Drama           317.0    4.429022
# 296           Comedy|Crime|Drama|Thriller           307.0    4.197068
# 593                 Crime|Horror|Thriller           279.0    4.161290
# 2571               Action|Sci-Fi|Thriller           278.0    4.192446
# 260               Action|Adventure|Sci-Fi           251.0    4.231076
# 480      Action|Adventure|Sci-Fi|Thriller           238.0    3.750000
# 110                      Action|Drama|War           237.0    4.031646
# 589                         Action|Sci-Fi           224.0    3.970982
# 527                             Drama|War           220.0    4.225000

# %% [markdown]
# # Uma segunda heurística

# %% [markdown]
# ### Seria recomendado filmes com nota media mais alto tento pelo menos mais de 50 votos

# %%
filmes.sort_values('nota_media', ascending = False).head(10)
# Out:
#                                             titulo                   generos  \
# filmeId
# 88448        Paper Birds (Pájaros de papel) (2010)              Comedy|Drama
# 100556                  Act of Killing, The (2012)               Documentary
# 143031                             Jump In! (2007)      Comedy|Drama|Romance
# 143511                                Human (2015)               Documentary
# 143559                         L.A. Slasher (2015)      Comedy|Crime|Fantasy
# 6201                              Lady Jane (1986)             Drama|Romance
# 102217              Bill Hicks: Revelations (1993)                    Comedy
# 102084                Justice League: Doom (2012)   Action|Animation|Fantasy
# 6192     Open Hearts (Elsker dig for evigt) (2002)                   Romance
# 145994                      Formula of Love (1984)                    Comedy
#
#          total_de_votos  nota_media
# filmeId
# 88448               1.0         5.0
# 100556              1.0         5.0
# 143031              1.0         5.0
# 143511              1.0         5.0
# 143559              1.0         5.0
# 6201                1.0         5.0
# 102217              1.0         5.0
# 102084              1.0         5.0
# 6192                1.0         5.0
# 145994              1.0         5.0

# %%
filmes.query('total_de_votos >= 10').sort_values('nota_media', ascending = False).head(10)
# Out:
#                                         titulo           generos  \
# filmeId
# 1041                     Secrets & Lies (1996)             Drama
# 3451       Guess Who's Coming to Dinner (1967)             Drama
# 1178                     Paths of Glory (1957)         Drama|War
# 1104          Streetcar Named Desire, A (1951)             Drama
# 2360          Celebration, The (Festen) (1998)             Drama
# 1217                                Ran (1985)         Drama|War
# 318           Shawshank Redemption, The (1994)       Crime|Drama
# 951                     His Girl Friday (1940)    Comedy|Romance
# 1927     All Quiet on the Western Front (1930)  Action|Drama|War
# 3468                       Hustler, The (1961)             Drama
#
#          total_de_votos  nota_media
# filmeId
# 1041               11.0    4.590909
# 3451               11.0    4.545455
# 1178               12.0    4.541667
# 1104               20.0    4.475000
# 2360               12.0    4.458333
# 1217               15.0    4.433333
# 318               317.0    4.429022
# 951                14.0    4.392857
# 1927               10.0    4.350000
# 3468               18.0    4.333333

# %%
filmes_com_mais_de_50_votos = filmes.query('total_de_votos >= 50')
filmes_com_mais_de_50_votos.sort_values('nota_media', ascending = False).head(10)
# Out:
#                                                     titulo  \
# filmeId
# 318                       Shawshank Redemption, The (1994)
# 858                                  Godfather, The (1972)
# 2959                                     Fight Club (1999)
# 1276                                 Cool Hand Luke (1967)
# 750      Dr. Strangelove or: How I Learned to Stop Worr...
# 904                                     Rear Window (1954)
# 1221                        Godfather: Part II, The (1974)
# 48516                                 Departed, The (2006)
# 1213                                     Goodfellas (1990)
# 912                                      Casablanca (1942)
#
#                              generos  total_de_votos  nota_media
# filmeId
# 318                      Crime|Drama           317.0    4.429022
# 858                      Crime|Drama           192.0    4.289062
# 2959     Action|Crime|Drama|Thriller           218.0    4.272936
# 1276                           Drama            57.0    4.271930
# 750                       Comedy|War            97.0    4.268041
# 904                 Mystery|Thriller            84.0    4.261905
# 1221                     Crime|Drama           129.0    4.259690
# 48516           Crime|Drama|Thriller           107.0    4.252336
# 1213                     Crime|Drama           126.0    4.250000
# 912                    Drama|Romance           100.0    4.240000

# %% [markdown]
# # Terceira heurística

# %% [markdown]
# ### Recomenda filmes com o ultimo genero de filme visto tirando os que já foram vistos

# %%
eu_assisti = [1,21,19,10,11,7,2]
filmes.loc[eu_assisti]
# Out:
#                                         titulo  \
# filmeId
# 1                             Toy Story (1995)
# 21                           Get Shorty (1995)
# 19       Ace Ventura: When Nature Calls (1995)
# 10                            GoldenEye (1995)
# 11              American President, The (1995)
# 7                               Sabrina (1995)
# 2                               Jumanji (1995)
#
#                                              generos  total_de_votos  \
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 21                             Comedy|Crime|Thriller            89.0
# 19                                            Comedy            88.0
# 10                         Action|Adventure|Thriller           132.0
# 11                              Comedy|Drama|Romance            70.0
# 7                                     Comedy|Romance            54.0
# 2                         Adventure|Children|Fantasy           110.0
#
#          nota_media
# filmeId
# 1          3.920930
# 21         3.494382
# 19         2.727273
# 10         3.496212
# 11         3.671429
# 7          3.185185
# 2          3.431818

# %%
aventura_infantil_e_fantasia = filmes_com_mais_de_50_votos.query('generos == "Adventure|Children|Fantasy"')
aventura_infantil_e_fantasia.drop(eu_assisti, errors = 'ignore').sort_values('nota_media', ascending = False).head(10)
# Out:
#                                                     titulo  \
# filmeId
# 4896     Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 41566    Chronicles of Narnia: The Lion, the Witch and ...
#
#                             generos  total_de_votos  nota_media
# filmeId
# 4896     Adventure|Children|Fantasy           107.0    3.761682
# 41566    Adventure|Children|Fantasy            62.0    3.443548

# %% [markdown]
# # Collaborative filtering X Content based filtering
#
# #### Filtra baseado na colaboração dos usuarios
# #### Filtra baseado no conteudo

# %% [markdown]
# # Quarta heurística

# %% [markdown]
# ### Procura pessoas similares pessolas que gostam dos mesmos filmes ou que não gostaram dos mesmos filmes

# %%
# - João: deu nota 4 no filme toy story
# - Maria: deu nota 5 no filme toy story
# - Paulo: deu nota 3 no filme toy story
# - Joana: deu nota 3.5 no filme toy story

# %%
# joao = [4,4.5]
# maria = [5,5]

# %%
import matplotlib.pyplot as plt
plt.plot(4,4.5, 'go')
plt.plot(5,5, 'yo')

plt.legend(['João', 'Maria'])
plt.title('Calculando a distância entre dois ususários')

# desenhando o triangulo
plt.plot([4,5],[4.5,5],color = 'b' , linestyle = '-')
plt.plot([4,5],[4.5,4.5],color = 'b' , linestyle = '-')
plt.plot([5,5],[4.5,5],color = 'b' , linestyle = '-')

# %%
import numpy as np

joao = np.array([4,4.5])
maria = np.array([5,5])

joao - maria
# Out:
# array([-1. , -0.5])

# %%
from math import sqrt

def pitagoras(a,b):
    (delta_x,delta_y) = a - b
    return sqrt(delta_x * delta_x + delta_y * delta_y)

pitagoras(joao, maria)
# Out:
# 1.118033988749895

# %%
# mesma coisa

def pitagoras(a,b):
    return np.linalg.norm(a - b)

pitagoras(joao, maria)
# Out:
# 1.118033988749895

# %%
plt.plot(4,4.5, 'go')
plt.plot(5,5, 'yo')
plt.plot(3.5,4.5, 'bo')

plt.legend(['João', 'Maria', 'Joaquina'])
plt.title('Calculando a distância entre dois ususários')
# Out:
# Text(0.5, 1.0, 'Calculando a distância entre dois ususários')

# %%
joaquina = np.array([3.5,4.5])

print(pitagoras(joao, maria))
print(pitagoras(joao, joaquina))
# Out:
# 1.118033988749895
# 0.5

# %% [markdown]
# # Distância entre usuários do DataSet

# %%
def distancia_de_vetores(a,b):
    return np.linalg.norm(a - b)

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
def notas_do_usuario(usuario):
    notas_do_usuario = notas.query('usuarioId == %d' %usuario)
    notas_do_usuario = notas_do_usuario[['filmeId', 'nota']].set_index('filmeId')
    return notas_do_usuario

# %%
usuario1 = notas_do_usuario(1)
usuario4 = notas_do_usuario(4)

# %%
usuario1.head()
# Out:
#          nota
# filmeId
# 1         4.0
# 3         4.0
# 6         4.0
# 47        5.0
# 50        5.0

# %%
usuario4.head()
# Out:
#          nota
# filmeId
# 21        3.0
# 32        2.0
# 45        3.0
# 47        2.0
# 52        3.0

# %%
# pega todos os filmes do usuario1 e procurando no usuario4 
# dropna: tira os vazios

diferencas = usuario1.join(usuario4, lsuffix = '_esquerda', rsuffix = '_direita').dropna()
distancia_de_vetores(diferencas['nota_esquerda'],diferencas['nota_direita'])
# Out:
# 11.135528725660043

# %%
def distancia_de_usuarios(usuario_id1,usuario_id2):
    notas1 = notas_do_usuario(usuario_id1)
    notas2 = notas_do_usuario(usuario_id2)
    diferencas = notas1.join(notas2, lsuffix = '_esquerda', rsuffix = '_direita').dropna()
    distancia = distancia_de_vetores(diferencas['nota_esquerda'],diferencas['nota_direita'])
    return [usuario_id1,usuario_id2,distancia]

# %%
distancia_de_usuarios(1,4)
# Out:
# [1, 4, 11.135528725660043]

# %%
quantidade_de_usuarios = len(notas['usuarioId'].unique())
print('Temos %d usuarios'%quantidade_de_usuarios)
# Out:
# Temos 610 usuarios

# %%
#maneira imperativa

def distancia_de_todos(voce_id):
    distancias = []
    for usuario_id in notas['usuarioId'].unique():
        informacoes = distancia_de_usuarios(voce_id,usuario_id)
        distancias.append(informacoes)
    return distancias
    
distancia_de_todos(1)[:5]
# Out:
# [[1, 1, 0.0],
#  [1, 2, 1.4142135623730951],
#  [1, 3, 8.200609733428363],
#  [1, 4, 11.135528725660043],
#  [1, 5, 3.7416573867739413]]

# %%
def distancia_de_todos(voce_id):
    todos_os_usuarios = notas['usuarioId'].unique()
    distancias = [distancia_de_usuarios(voce_id,usuario_id) for usuario_id in todos_os_usuarios]
    distancias = pd.DataFrame(distancias, columns = ['voce','outra_pessoa','distancia'])
    return distancias
    
distancia_de_todos(1).head(10)
# Out:
#    voce  outra_pessoa  distancia
# 0     1             1   0.000000
# 1     1             2   1.414214
# 2     1             3   8.200610
# 3     1             4  11.135529
# 4     1             5   3.741657
# 5     1             6   8.602325
# 6     1             7   7.106335
# 7     1             8   3.741657
# 8     1             9   1.000000
# 9     1            10   7.858117

# %%
notas_do_usuario(1).join(notas_do_usuario(10), lsuffix = '_1', rsuffix = '2').dropna()
# Out:
#          nota_1  nota2
# filmeId
# 296         3.0    1.0
# 356         4.0    3.5
# 2571        5.0    0.5
# 2858        5.0    1.0
# 2959        5.0    0.5
# 3578        5.0    4.0

# %% [markdown]
# # Usuário sem filmes em comum são colocadas bem distantes uma da outra

# %%
def distancia_de_usuarios(usuario_id1,usuario_id2, minino = 5):
    notas1 = notas_do_usuario(usuario_id1)
    notas2 = notas_do_usuario(usuario_id2)
    diferencas = notas1.join(notas2, lsuffix = '_esquerda', rsuffix = '_direita').dropna()
    
    if(len(diferencas) < minino):
        return [usuario_id1, usuario_id2, 100000]
    
    distancia = distancia_de_vetores(diferencas['nota_esquerda'],diferencas['nota_direita'])
    return [usuario_id1,usuario_id2,distancia]

# %%
def distancia_de_todos(voce_id):
    todos_os_usuarios = notas['usuarioId'].unique()
    distancias = [distancia_de_usuarios(voce_id,usuario_id) for usuario_id in todos_os_usuarios]
    distancias = pd.DataFrame(distancias, columns = ['voce','outra_pessoa','distancia'])
    return distancias
    
distancia_de_todos(1).head(10)
# Out:
#    voce  outra_pessoa      distancia
# 0     1             1       0.000000
# 1     1             2  100000.000000
# 2     1             3       8.200610
# 3     1             4      11.135529
# 4     1             5       3.741657
# 5     1             6       8.602325
# 6     1             7       7.106335
# 7     1             8       3.741657
# 8     1             9       1.000000
# 9     1            10       7.858117

# %%
def mais_proximos_de(voce_id):
    distancias = distancia_de_todos(voce_id)
    distancias = distancias.sort_values('distancia')
    distancias = distancias.set_index('outra_pessoa').drop(voce_id)
    return distancias

# %%
mais_proximos_de(1).head()
# Out:
#               voce  distancia
# outra_pessoa
# 77               1   0.000000
# 511              1   0.500000
# 366              1   0.707107
# 523              1   1.000000
# 49               1   1.000000

# %% [markdown]
# # Parametro para teste

# %%
def mais_proximos_de(voce_id, n = None):
    distancias = distancia_de_todos(voce_id, n = n)
    distancias = distancias.sort_values('distancia')
    distancias = distancias.set_index('outra_pessoa').drop(voce_id)
    return distancias

# %%
def distancia_de_todos(voce_id, n = None):
    todos_os_usuarios = notas['usuarioId'].unique()
    
    if n:
        todos_os_usuarios = todos_os_usuarios[:n]
    distancias = [distancia_de_usuarios(voce_id,usuario_id) for usuario_id in todos_os_usuarios]
    distancias = pd.DataFrame(distancias, columns = ['voce','outra_pessoa','distancia'])
    return distancias

# %%
mais_proximos_de(1,n = 50)
# Out:
#               voce      distancia
# outra_pessoa
# 49               1       1.000000
# 9                1       1.000000
# 13               1       1.414214
# 25               1       1.414214
# 30               1       1.802776
# 35               1       2.236068
# 26               1       2.236068
# 46               1       3.316625
# 8                1       3.741657
# 44               1       3.741657
# 5                1       3.741657
# 37               1       4.000000
# 48               1       4.123106
# 11               1       4.242641
# 24               1       4.415880
# 29               1       4.555217
# 31               1       4.582576
# 17               1       4.609772
# 43               1       4.795832
# 14               1       5.000000
# 32               1       5.196152
# 22               1       5.244044
# 23               1       5.408327
# 38               1       5.567764
# 15               1       5.852350
# 33               1       5.916080
# 47               1       6.244998
# 34               1       6.363961
# 20               1       6.480741
# 36               1       6.519202
# 40               1       6.855655
# 7                1       7.106335
# 16               1       7.228416
# 50               1       7.331439
# 10               1       7.858117
# 3                1       8.200610
# 18               1       8.426150
# 6                1       8.602325
# 21               1       9.096703
# 27               1       9.219544
# 41               1      10.198039
# 45               1      10.653638
# 39               1      11.090537
# 4                1      11.135529
# 42               1      12.000000
# 28               1      14.882876
# 19               1      17.606817
# 2                1  100000.000000
# 12               1  100000.000000

# %%
def distancia_de_usuarios(usuario_id1,usuario_id2, minino = 5):
    notas1 = notas_do_usuario(usuario_id1)
    notas2 = notas_do_usuario(usuario_id2)
    diferencas = notas1.join(notas2, lsuffix = '_esquerda', rsuffix = '_direita').dropna()
    
    if(len(diferencas) < minino):
        return None
    
    distancia = distancia_de_vetores(diferencas['nota_esquerda'],diferencas['nota_direita'])
    return [usuario_id1,usuario_id2,distancia]

# %%
def distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = None):
    todos_os_usuarios = notas['usuarioId'].unique()
    
    if numero_de_usuarios_a_analisar:
        todos_os_usuarios = todos_os_usuarios[:numero_de_usuarios_a_analisar]
    distancias = [distancia_de_usuarios(voce_id,usuario_id) for usuario_id in todos_os_usuarios]
    distancias = list(filter(None, distancias))
    distancias = pd.DataFrame(distancias, columns = ['voce','outra_pessoa','distancia'])
    return distancias

# %%
def mais_proximos_de(voce_id, numero_de_usuarios_a_analisar = None):
    distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar)
    distancias = distancias.sort_values('distancia')
    distancias = distancias.set_index('outra_pessoa').drop(voce_id)
    return distancias

# %%
# n -> vai ser a quantidade de pessoas que ele vai olhar (podem fazer isso quando tem uma grande quantidade de dados)
mais_proximos_de(1, numero_de_usuarios_a_analisar = 50)
# Out:
#               voce  distancia
# outra_pessoa
# 49               1   1.000000
# 9                1   1.000000
# 25               1   1.414214
# 13               1   1.414214
# 30               1   1.802776
# 35               1   2.236068
# 26               1   2.236068
# 46               1   3.316625
# 8                1   3.741657
# 5                1   3.741657
# 44               1   3.741657
# 37               1   4.000000
# 48               1   4.123106
# 11               1   4.242641
# 24               1   4.415880
# 29               1   4.555217
# 31               1   4.582576
# 17               1   4.609772
# 43               1   4.795832
# 14               1   5.000000
# 32               1   5.196152
# 22               1   5.244044
# 23               1   5.408327
# 38               1   5.567764
# 15               1   5.852350
# 33               1   5.916080
# 47               1   6.244998
# 34               1   6.363961
# 20               1   6.480741
# 36               1   6.519202
# 40               1   6.855655
# 7                1   7.106335
# 16               1   7.228416
# 50               1   7.331439
# 10               1   7.858117
# 3                1   8.200610
# 18               1   8.426150
# 6                1   8.602325
# 21               1   9.096703
# 27               1   9.219544
# 41               1  10.198039
# 45               1  10.653638
# 39               1  11.090537
# 4                1  11.135529
# 42               1  12.000000
# 28               1  14.882876
# 19               1  17.606817

# %%
voce = 1
def sugere_para(voce, numero_de_usuarios_a_analisar = None):
    notas_de_voce = notas_do_usuario(voce)
    filmes_que_voce_ja_viu = notas_de_voce.index

    similares = mais_proximos_de(voce, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
    similar = similares.iloc[0].name
    notas_do_similar = notas_do_usuario(similar)
    notas_do_similar = notas_do_similar.drop(filmes_que_voce_ja_viu, errors = 'ignore')
    recomentacoes = notas_do_similar.sort_values('nota', ascending = False)
    return recomentacoes.join(filmes)

# %%
sugere_para(1, numero_de_usuarios_a_analisar = 50).head()
# Out:
#          nota                            titulo  \
# filmeId
# 1200      4.5                     Aliens (1986)
# 4022      4.5                  Cast Away (2000)
# 47099     4.5  Pursuit of Happyness, The (2006)
# 79132     4.5                  Inception (2010)
# 109487    4.5               Interstellar (2014)
#
#                                                  generos  total_de_votos  \
# filmeId
# 1200                      Action|Adventure|Horror|Sci-Fi           126.0
# 4022                                               Drama           100.0
# 47099                                              Drama            46.0
# 79132    Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX           143.0
# 109487                                       Sci-Fi|IMAX            73.0
#
#          nota_media
# filmeId
# 1200       3.964286
# 4022       3.700000
# 47099      3.793478
# 79132      4.066434
# 109487     3.993151

# %%
sugere_para(1).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 8636      5.0                                Spider-Man 2 (2004)
# 58559     5.0                            Dark Knight, The (2008)
# 33794     5.0                               Batman Begins (2005)
# 4993      5.0  Lord of the Rings: The Fellowship of the Ring,...
# 5349      5.0                                  Spider-Man (2002)
#
#                                   generos  total_de_votos  nota_media
# filmeId
# 8636         Action|Adventure|Sci-Fi|IMAX            79.0    3.803797
# 58559             Action|Crime|Drama|IMAX           149.0    4.238255
# 33794                   Action|Crime|IMAX           116.0    3.862069
# 4993                    Adventure|Fantasy           198.0    4.106061
# 5349     Action|Adventure|Sci-Fi|Thriller           122.0    3.540984

# %% [markdown]
# # Sugerindo baseado em vários usuarios

# %%
def mais_proximos_de(voce_id,n_mais_proximos = 10 ,numero_de_usuarios_a_analisar = None):
    distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar)
    distancias = distancias.sort_values('distancia')
    distancias = distancias.set_index('outra_pessoa').drop(voce_id)
    return distancias.head(n_mais_proximos)

# %%
mais_proximos_de(1, n_mais_proximos = 2,numero_de_usuarios_a_analisar = 300)
# Out:
#               voce  distancia
# outra_pessoa
# 77               1        0.0
# 258              1        1.0

# %%
def sugere_para(voce, n_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
    notas_de_voce = notas_do_usuario(voce)
    filmes_que_voce_ja_viu = notas_de_voce.index

    similares = mais_proximos_de(voce, n_mais_proximos = n_mais_proximos ,numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
    usuarios_similares = similares.index
    notas_dos_silimares = notas.set_index('usuarioId').loc[usuarios_similares]
    recomendacoes = notas_dos_silimares.groupby('filmeId').mean()[['nota']] # os dois [[]], faz com que eles continuem em um DataFrame
    recomendacoes = recomendacoes.sort_values('nota', ascending = False)
    return recomendacoes.join(filmes).head()

# %%
voce = 1
n_mais_proximos = 10

numero_de_usuarios_a_analisar = 50

sugere_para(1, numero_de_usuarios_a_analisar = 300).head()
# Out:
#          nota                                          titulo  \
# filmeId
# 187593    5.0                               Deadpool 2 (2018)
# 802       5.0                               Phenomenon (1996)
# 534       5.0                              Shadowlands (1993)
# 1172      5.0  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
# 515       5.0                  Remains of the Day, The (1993)
#
#                       generos  total_de_votos  nota_media
# filmeId
# 187593   Action|Comedy|Sci-Fi            12.0    3.875000
# 802             Drama|Romance            46.0    3.336957
# 534             Drama|Romance            14.0    3.607143
# 1172                    Drama            34.0    4.161765
# 515             Drama|Romance            24.0    3.604167

# %%
sugere_para(1).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 1704      5.0                           Good Will Hunting (1997)
# 57504     5.0  Girl Who Leapt Through Time, The (Toki o kaker...
# 38304     5.0                No Direction Home: Bob Dylan (2005)
# 48394     5.0   Pan's Labyrinth (Laberinto del fauno, El) (2006)
# 2300      5.0                              Producers, The (1968)
#
#                                        generos  total_de_votos  nota_media
# filmeId
# 1704                             Drama|Romance           141.0    4.078014
# 57504    Animation|Comedy|Drama|Romance|Sci-Fi            10.0    4.100000
# 38304                              Documentary             4.0    4.625000
# 48394                   Drama|Fantasy|Thriller            81.0    3.814815
# 2300                                    Comedy            33.0    3.969697

# %% [markdown]
# # k-nearest neighbors (KNN)

# %%
def knn(voce_id,k_mais_proximos = 10 ,numero_de_usuarios_a_analisar = None):
    distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar)
    distancias = distancias.sort_values('distancia')
    distancias = distancias.set_index('outra_pessoa').drop(voce_id)
    return distancias.head(k_mais_proximos)

# %%
def sugere_para(voce, k_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
    notas_de_voce = notas_do_usuario(voce)
    filmes_que_voce_ja_viu = notas_de_voce.index

    similares = knn(voce, k_mais_proximos = k_mais_proximos ,numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
    usuarios_similares = similares.index
    notas_dos_silimares = notas.set_index('usuarioId').loc[usuarios_similares]
    recomendacoes = notas_dos_silimares.groupby('filmeId').mean()[['nota']] # os dois [[]], faz com que eles continuem em um DataFrame
    recomendacoes = recomendacoes.sort_values('nota', ascending = False)
    return recomendacoes.join(filmes).head()

# %% [markdown]
# # Testar um usuário novo

# %%
filmes.loc[[122904,1246,2529,2329,2324,1,7,2,1196,260]]
# Out:
#                                                     titulo  \
# filmeId
# 122904                                     Deadpool (2016)
# 1246                             Dead Poets Society (1989)
# 2529                             Planet of the Apes (1968)
# 2329                             American History X (1998)
# 2324            Life Is Beautiful (La Vita è bella) (1997)
# 1                                         Toy Story (1995)
# 7                                           Sabrina (1995)
# 2                                           Jumanji (1995)
# 1196     Star Wars: Episode V - The Empire Strikes Back...
# 260              Star Wars: Episode IV - A New Hope (1977)
#
#                                              generos  total_de_votos  \
# filmeId
# 122904                Action|Adventure|Comedy|Sci-Fi            54.0
# 1246                                           Drama            86.0
# 2529                             Action|Drama|Sci-Fi            56.0
# 2329                                     Crime|Drama           129.0
# 2324                        Comedy|Drama|Romance|War            88.0
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 7                                     Comedy|Romance            54.0
# 2                         Adventure|Children|Fantasy           110.0
# 1196                         Action|Adventure|Sci-Fi           211.0
# 260                          Action|Adventure|Sci-Fi           251.0
#
#          nota_media
# filmeId
# 122904     3.833333
# 1246       3.959302
# 2529       3.803571
# 2329       4.217054
# 2324       4.147727
# 1          3.920930
# 7          3.185185
# 2          3.431818
# 1196       4.215640
# 260        4.231076

# %%
def novo_usuarios(dados):
    novo_usuario = notas['usuarioId'].max()+1
    notas_do_usuario_novo = pd.DataFrame(dados,columns = ['filmeId', 'nota'])
    notas_do_usuario_novo['usuarioId'] = novo_usuario
    return pd.concat([notas, notas_do_usuario_novo])

# %%
notas = novo_usuarios([[122904,2],[1246,5],[2529,2],[2329,5],[2324,5],[1,2],[7,0.5],[2,2],[1196,1],[260,1]])
notas.tail()
# Out:
#    usuarioId  filmeId  nota  momento
# 5        611        1   2.0      NaN
# 6        611        7   0.5      NaN
# 7        611        2   2.0      NaN
# 8        611     1196   1.0      NaN
# 9        611      260   1.0      NaN

# %%
sugere_para(611).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 171495    5.0                                             Cosmos
# 81847     5.0                                     Tangled (2010)
# 1873      5.0                             Misérables, Les (1998)
# 8014      5.0  Spring, Summer, Fall, Winter... and Spring (Bo...
# 103141    5.0                         Monsters University (2013)
#
#                                                    generos  total_de_votos  \
# filmeId
# 171495                                  (no genres listed)             2.0
# 81847    Animation|Children|Comedy|Fantasy|Musical|Roma...            24.0
# 1873                               Crime|Drama|Romance|War            10.0
# 8014                                                 Drama            10.0
# 103141                          Adventure|Animation|Comedy            16.0
#
#          nota_media
# filmeId
# 171495     4.500000
# 81847      3.916667
# 1873       3.750000
# 8014       4.250000
# 103141     3.875000

# %% [markdown]
# # Utilizar somente as notas de filmes com amis de 50 votos

# %%
notas = notas.set_index('filmeId').loc[filmes_com_mais_de_50_votos.index]
notas.head()
# Out:
#          usuarioId  nota       momento
# filmeId
# 1                1   4.0  9.649827e+08
# 1                5   4.0  8.474350e+08
# 1                7   4.5  1.106636e+09
# 1               15   2.5  1.510578e+09
# 1               17   4.5  1.305696e+09

# %%
notas = notas.reset_index()
notas.head()
# Out:
#    filmeId  usuarioId  nota       momento
# 0        1          1   4.0  9.649827e+08
# 1        1          5   4.0  8.474350e+08
# 2        1          7   4.5  1.106636e+09
# 3        1         15   2.5  1.510578e+09
# 4        1         17   4.5  1.305696e+09

# %%
sugere_para(611).head()
# Out:
#              nota                          titulo  \
# filmeId
# 112852   5.000000  Guardians of the Galaxy (2014)
# 74458    4.750000           Shutter Island (2010)
# 71535    4.666667               Zombieland (2009)
# 78499    4.500000              Toy Story 3 (2010)
# 2804     4.500000       Christmas Story, A (1983)
#
#                                                   generos  total_de_votos  \
# filmeId
# 112852                            Action|Adventure|Sci-Fi            59.0
# 74458                              Drama|Mystery|Thriller            67.0
# 71535                                Action|Comedy|Horror            53.0
# 78499    Adventure|Animation|Children|Comedy|Fantasy|IMAX            55.0
# 2804                                      Children|Comedy            55.0
#
#          nota_media
# filmeId
# 112852     4.050847
# 74458      4.022388
# 71535      3.877358
# 78499      4.109091
# 2804       3.972727

# %%
def sugere_para(voce, k_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
    notas_de_voce = notas_do_usuario(voce)
    filmes_que_voce_ja_viu = notas_de_voce.index

    similares = knn(voce, k_mais_proximos = k_mais_proximos ,numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
    usuarios_similares = similares.index
    notas_dos_silimares = notas.set_index('usuarioId').loc[usuarios_similares]
    recomendacoes = notas_dos_silimares.groupby('filmeId').mean()[['nota']] # os dois [[]], faz com que eles continuem em um DataFrame
    aparicoes = notas_dos_silimares.groupby('filmeId').count()[['nota']]
    
    
    filtro_minino = k_mais_proximos / 2
    recomendacoes = recomendacoes.join(aparicoes, lsuffix = '_media_dos_usuarios', rsuffix = '_aparicoes_nos_usuarios')
    recomendacoes.query('nota_aparicoes_nos_usuarios >= %.2f' % filtro_minino)
    recomendacoes = recomendacoes.sort_values('nota_media_dos_usuarios', ascending = False)
    recomendacoes = recomendacoes.drop(filmes_que_voce_ja_viu, errors = 'ignore')
    return recomendacoes.join(filmes)

# %%
def knn(voce_id,k_mais_proximos = 10 ,numero_de_usuarios_a_analisar = None):
    distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar)
    distancias = distancias.sort_values('distancia')
    distancias = distancias.set_index('outra_pessoa').drop(voce_id, errors = 'ignore')
    return distancias.head(k_mais_proximos)

# %%
sugere_para(1)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 56174                        5.0                            1
# 48394                        5.0                            1
# 4995                         5.0                            2
# 1221                         5.0                            1
# 1704                         5.0                            1
# ...                          ...                          ...
# 32587                        3.0                            1
# 7438                         3.0                            2
# 3948                         3.0                            1
# 5418                         2.5                            1
# 4878                         1.0                            1
#
#                                                    titulo  \
# filmeId
# 56174                                  I Am Legend (2007)
# 48394    Pan's Labyrinth (Laberinto del fauno, El) (2006)
# 4995                             Beautiful Mind, A (2001)
# 1221                       Godfather: Part II, The (1974)
# 1704                             Good Will Hunting (1997)
# ...                                                   ...
# 32587                                     Sin City (2005)
# 7438                             Kill Bill: Vol. 2 (2004)
# 3948                              Meet the Parents (2000)
# 5418                          Bourne Identity, The (2002)
# 4878                                  Donnie Darko (2001)
#
#                                          generos  total_de_votos  nota_media
# filmeId
# 56174         Action|Horror|Sci-Fi|Thriller|IMAX            62.0    3.483871
# 48394                     Drama|Fantasy|Thriller            81.0    3.814815
# 4995                               Drama|Romance           123.0    4.000000
# 1221                                 Crime|Drama           129.0    4.259690
# 1704                               Drama|Romance           141.0    4.078014
# ...                                          ...             ...         ...
# 32587    Action|Crime|Film-Noir|Mystery|Thriller            84.0    3.857143
# 7438                       Action|Drama|Thriller           110.0    3.868182
# 3948                                      Comedy            91.0    3.417582
# 5418                     Action|Mystery|Thriller           112.0    3.816964
# 4878               Drama|Mystery|Sci-Fi|Thriller           109.0    3.981651
#
# [86 rows x 6 columns]

# %%
sugere_para(611).head(10)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 112852                  5.000000                            1
# 74458                   4.750000                            4
# 71535                   4.666667                            3
# 78499                   4.500000                            2
# 2804                    4.500000                            3
# 300                     4.500000                            1
# 1090                    4.500000                            2
# 76093                   4.500000                            2
# 1203                    4.500000                            3
# 318                     4.500000                            8
#
#                                    titulo  \
# filmeId
# 112852     Guardians of the Galaxy (2014)
# 74458               Shutter Island (2010)
# 71535                   Zombieland (2009)
# 78499                  Toy Story 3 (2010)
# 2804            Christmas Story, A (1983)
# 300                      Quiz Show (1994)
# 1090                       Platoon (1986)
# 76093     How to Train Your Dragon (2010)
# 1203                  12 Angry Men (1957)
# 318      Shawshank Redemption, The (1994)
#
#                                                   generos  total_de_votos  \
# filmeId
# 112852                            Action|Adventure|Sci-Fi            59.0
# 74458                              Drama|Mystery|Thriller            67.0
# 71535                                Action|Comedy|Horror            53.0
# 78499    Adventure|Animation|Children|Comedy|Fantasy|IMAX            55.0
# 2804                                      Children|Comedy            55.0
# 300                                                 Drama            81.0
# 1090                                            Drama|War            63.0
# 76093           Adventure|Animation|Children|Fantasy|IMAX            53.0
# 1203                                                Drama            57.0
# 318                                           Crime|Drama           317.0
#
#          nota_media
# filmeId
# 112852     4.050847
# 74458      4.022388
# 71535      3.877358
# 78499      4.109091
# 2804       3.972727
# 300        3.518519
# 1090       3.984127
# 76093      3.943396
# 1203       4.149123
# 318        4.429022

# %%
sugere_para(611, k_mais_proximos = 20).head(10)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 71535                   4.666667                            3
# 112852                  4.500000                            2
# 8874                    4.428571                            7
# 1090                    4.400000                            5
# 16                      4.357143                            7
# 78499                   4.333333                            3
# 593                     4.266667                           15
# 296                     4.264706                           17
# 300                     4.250000                            2
# 2329                    4.227273                           11
#
#                                    titulo  \
# filmeId
# 71535                   Zombieland (2009)
# 112852     Guardians of the Galaxy (2014)
# 8874             Shaun of the Dead (2004)
# 1090                       Platoon (1986)
# 16                          Casino (1995)
# 78499                  Toy Story 3 (2010)
# 593      Silence of the Lambs, The (1991)
# 296                   Pulp Fiction (1994)
# 300                      Quiz Show (1994)
# 2329            American History X (1998)
#
#                                                   generos  total_de_votos  \
# filmeId
# 71535                                Action|Comedy|Horror            53.0
# 112852                            Action|Adventure|Sci-Fi            59.0
# 8874                                        Comedy|Horror            77.0
# 1090                                            Drama|War            63.0
# 16                                            Crime|Drama            82.0
# 78499    Adventure|Animation|Children|Comedy|Fantasy|IMAX            55.0
# 593                                 Crime|Horror|Thriller           279.0
# 296                           Comedy|Crime|Drama|Thriller           307.0
# 300                                                 Drama            81.0
# 2329                                          Crime|Drama           129.0
#
#          nota_media
# filmeId
# 71535      3.877358
# 112852     4.050847
# 8874       4.006494
# 1090       3.984127
# 16         3.926829
# 78499      4.109091
# 593        4.161290
# 296        4.197068
# 300        3.518519
# 2329       4.217054
